# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('microsoft_stocks.csv')

# %%
df.head()
# Out:
#          Date       High        Low       Open      Close      Volume  \
# 0  2015-01-12  47.540001  46.360001  47.419998  46.599998  23651900.0
# 1  2015-01-13  47.910000  46.060001  46.970001  46.360001  35270600.0
# 2  2015-01-14  46.240002  45.619999  45.959999  45.959999  29719600.0
# 3  2015-01-15  46.380001  45.410000  46.220001  45.480000  32750800.0
# 4  2015-01-16  46.279999  45.169998  45.310001  46.240002  35695300.0
#
#    Adj Close
# 0  40.786396
# 1  40.576340
# 2  40.226257
# 3  39.806129
# 4  40.471313

# %%
df.shape
# Out:
# (1925, 7)

# %%
df.isnull().sum()
# Out:
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
df.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1925.000000  1925.000000  1925.000000  1925.000000  1.925000e+03
# mean    140.301455   137.482982   138.934888   138.967096  3.009687e+07
# std      89.000722    87.030367    88.066413    88.062951  1.397862e+07
# min      40.740002    39.720001    40.340000    40.290001  7.425600e+06
# 25%      61.410000    60.810001    61.009998    61.119999  2.150010e+07
# 50%     108.739998   106.290001   107.860001   107.639999  2.669610e+07
# 75%     215.000000   210.360001   213.100006   212.830002  3.426400e+07
# max     349.670013   342.200012   344.619995   343.109985  1.691640e+08
#
#          Adj Close
# count  1925.000000
# mean    134.947514
# std      89.136791
# min      35.359890
# 25%      56.459160
# 50%     102.966743
# 75%     209.119339
# max     340.882812

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %%
data = df[['Date','High','Low','Close','Open']]
data
# Out:
#             Date        High         Low       Close        Open
# 0     2015-01-12   47.540001   46.360001   46.599998   47.419998
# 1     2015-01-13   47.910000   46.060001   46.360001   46.970001
# 2     2015-01-14   46.240002   45.619999   45.959999   45.959999
# 3     2015-01-15   46.380001   45.410000   45.480000   46.220001
# 4     2015-01-16   46.279999   45.169998   46.240002   45.310001
# ...          ...         ...         ...         ...         ...
# 1920  2022-08-26  280.339996  267.980011  268.089996  279.079987
# 1921  2022-08-29  267.399994  263.850006  265.230011  265.850006
# 1922  2022-08-30  267.049988  260.660004  262.970001  266.670013
# 1923  2022-08-31  267.109985  261.329987  261.470001  265.390015
# 1924  2022-09-01  260.890015  255.410004  260.399994  258.869995
#
# [1925 rows x 5 columns]

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data.plot(x = 'Date', y = 'Close', kind='line', rot = 90)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot(x = 'Date', y = 'Volume', kind='line', rot = 90, figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data.plot(x = 'Date', kind='line', rot = 90)
# Out:
# <AxesSubplot:xlabel='Date'>
