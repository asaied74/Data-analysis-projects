# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('TeslaInc. ( TSLA ).csv')

# %%
df.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 1  2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2  2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 3  2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 4  2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 5  2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 6  2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 7  2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 8  2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 9  2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000

# %%
df.shape
# Out:
# (3077, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3077 entries, 0 to 3076
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3077 non-null   object
#  1   Open       3077 non-null   float64
#  2   High       3077 non-null   float64
#  3   Low        3077 non-null   float64
#  4   Close      3077 non-null   float64
#  5   Adj Close  3077 non-null   float64
#  6   Volume     3077 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 168.4+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3077.000000  3077.000000  3077.000000  3077.000000  3077.000000
# mean     55.502174    56.748047    54.161176    55.495537    55.495537
# std      93.913081    96.085026    91.517219    93.851345    93.851345
# min       1.076000     1.108667     0.998667     1.053333     1.053333
# 25%       8.192667     8.354667     7.970667     8.113333     8.113333
# 50%      15.983333    16.242001    15.687333    16.000668    16.000668
# 75%      23.586666    23.916668    23.229334    23.523333    23.523333
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  3.077000e+03
# mean   9.340392e+07
# std    8.235816e+07
# min    1.777500e+06
# 25%    4.144350e+07
# 50%    7.541550e+07
# 75%    1.173030e+08
# max    9.140820e+08

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %%
data_values = df[['Date', 'Open', 'High', 'Low', 'Close']]
data_values
# Out:
#             Date        Open        High         Low       Close
# 0     2010-06-30    1.719333    2.028000    1.553333    1.588667
# 1     2010-07-01    1.666667    1.728000    1.351333    1.464000
# 2     2010-07-02    1.533333    1.540000    1.247333    1.280000
# 3     2010-07-06    1.333333    1.333333    1.055333    1.074000
# 4     2010-07-07    1.093333    1.108667    0.998667    1.053333
# ...          ...         ...         ...         ...         ...
# 3072  2022-09-13  292.899994  297.399994  290.399994  292.130005
# 3073  2022-09-14  292.239990  306.000000  291.640015  302.609985
# 3074  2022-09-15  301.829987  309.119995  300.720001  303.750000
# 3075  2022-09-16  299.609985  303.709991  295.600006  303.350006
# 3076  2022-09-19  300.089996  309.839996  297.799988  309.070007
#
# [3077 rows x 5 columns]

# %%
data_values.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(x = 'Date', y = 'Adj Close', kind='line', rot = 90)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot(x = 'Date', y = 'Volume', kind='line', rot = 90, figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
